# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\meghli\Desktop\ffffinal.csv")

# %%
df.head()
# Out:
#     Temp  Pulse       Time
# 0  35.50   2767   17:43:24
# 1  35.50   1018   17:43:40
# 2  32.25   1475   17:43:55
# 3  30.44   1769   17:44:18
# 4  31.31   1691   17:44:34

# %%
df.plot(kind='line',x='Time',y='Temp',color='green')
plt.show()

# %%
df.plot(kind='line',x='Time',y='Pulse',color='red')
plt.show()

# %%
df2=df[(df['Pulse']>=4000)]
df2
# Out:
#       Temp  Pulse       Time
# 20   35.25   4095   17:48:44
# 24   36.31   4095   17:49:55
# 25   35.69   4095   17:50:11
# 30   35.38   4062   17:51:29
# 40   31.75   4095   17:54:05
# 43   30.19   4095   17:55:03
# 45   31.69   4058   17:55:35
# 51   33.75   4069   17:57:25
# 54   35.56   4095   17:58:12
# 55   35.69   4095   17:58:28
# 56   35.81   4095   17:58:43
# 57   36.00   4095   17:58:59
# 64   36.19   4095   18:00:48
# 68   32.50   4095   18:02:07
# 69   34.56   4095   18:02:22
# 70   41.81   4095   18:02:38
# 71   33.63   4095   18:02:53
# 72   36.50   4095   18:03:09
# 73   35.25   4095   18:03:24
# 74   35.38   4095   18:03:40
# 75   35.69   4095   18:03:55
# 76   36.31   4095   18:04:11
# 77   36.69   4095   18:04:27
# 83   35.94   4095   18:06:01
# 96   33.38   4095   18:09:42
# 97   33.88   4095   18:10:18
# 99   35.88   4066   18:11:11
# 122  31.62   4095   18:17:30
# 149  28.44   4095   18:26:31

# %%
df2.plot(kind='line',x='Time',y='Pulse')
plt.show()

# %%
df1=df[(df['Pulse']<=500)]
df1
# Out:
#       Temp  Pulse       Time
# 14   35.13      0   17:47:10
# 21   35.25      0   17:48:59
# 22   35.88      0   17:49:24
# 23   36.19      0   17:49:40
# 98   33.94      0   18:10:33
# 127  33.44      0   18:18:48
# 150  28.75      0   18:26:46
# 151  30.75      0   18:27:13

# %%
df1.plot(kind='line',x='Time',y='Pulse')
plt.show()

# %%
df3=df[(df['Temp']<=33)]
df3
# Out:
#       Temp  Pulse       Time
# 2    32.25   1475   17:43:55
# 3    30.44   1769   17:44:18
# 4    31.31   1691   17:44:34
# 38   32.50   3887   17:53:34
# 39   31.25   3733   17:53:49
# 40   31.75   4095   17:54:05
# 42   32.19   3983   17:54:48
# 43   30.19   4095   17:55:03
# 44   30.62   3923   17:55:19
# 45   31.69   4058   17:55:35
# 46   32.38   2819   17:55:50
# 47   32.69   2983   17:56:05
# 48   33.00   3113   17:56:21
# 68   32.50   4095   18:02:07
# 94   31.81   2778   18:09:10
# 95   32.63   2364   18:09:26
# 119  29.37   1610   18:16:23
# 120  29.31   1237   18:16:59
# 121  30.69   1423   18:17:15
# 122  31.62   4095   18:17:30
# 123  32.25   2949   18:17:46
# 124  32.75   2634   18:18:02
# 135  30.94   2768   18:21:51
# 136  30.81   2761   18:22:07
# 137  31.69   2762   18:22:23
# 138  32.44   2752   18:22:38
# 139  32.88   2775   18:22:54
# 148  30.19   2415   18:26:15
# 149  28.44   4095   18:26:31
# 150  28.75      0   18:26:46
# 151  30.75      0   18:27:13
# ...

# %%
df3.plot(kind='line',x='Time',y='Temp')
plt.show()

# %%
df4=df[(df['Temp']>=37)]
df4
# Out:
#      Temp  Pulse       Time
# 5   37.88   1713   17:44:50
# 67  41.44   1658   18:01:35
# 70  41.81   4095   18:02:38
# 93  37.44   2940   18:08:37

# %%
df4.plot(kind='line',x='Time',y='Temp')
plt.show()
